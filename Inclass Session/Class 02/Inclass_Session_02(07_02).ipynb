# %% [markdown]
# <a href="https://colab.research.google.com/github/NPranaya7/Data_690_Pranaya/blob/main/Inclass%20Session/Class%2002/Inclass_Session_02(07_02).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inclass Session_02
# - N Pranay manikanta
# - Date:07/02/2022

# %% [markdown]
# # 1.Data Exploration

# %%
import pandas as pd
import plotly.express as px
data = "https://raw.githubusercontent.com/DATA-690-SPRING-2022/WANG/main/assignment_02/survey.csv"

# %%
df = pd.read_csv(data)
df
# Out:
#                      Timestamp  ...             12. Other courses taking this semester
# 0    2022/01/25 5:14:48 PM EST  ...   Introduction to Data Science | DATA 601;SENG 601
# 1    2022/01/25 5:37:24 PM EST  ...  Introduction to Data Science | DATA 601;Platfo...
# 2    2022/01/25 7:12:07 PM EST  ...  Intro to Data Analysis and Machine Learning | ...
# 3    2022/01/25 7:26:31 PM EST  ...  Introduction to Data Science | DATA 601;Ethica...
# 4   2022/01/26 11:15:22 AM EST  ...  Introduction to Data Science | DATA 601;Platfo...
# 5    2022/01/26 1:03:34 PM EST  ...  Introduction to Data Science | DATA 601;ENMG 6...
# 6   2022/01/27 11:35:51 AM EST  ...  Platforms for Big Data Processing | DATA 603;S...
# 7    2022/01/27 6:36:02 PM EST  ...            Introduction to Data Science | DATA 601
# 8    2022/01/28 1:53:53 AM EST  ...  Intro to Data Analysis and Machine Learning | ...
# 9   2022/01/28 12:12:38 PM EST  ...                                            SENG601
# ...

# %%
df.head()
# Out:
#                     Timestamp  ...             12. Other courses taking this semester
# 0   2022/01/25 5:14:48 PM EST  ...   Introduction to Data Science | DATA 601;SENG 601
# 1   2022/01/25 5:37:24 PM EST  ...  Introduction to Data Science | DATA 601;Platfo...
# 2   2022/01/25 7:12:07 PM EST  ...  Intro to Data Analysis and Machine Learning | ...
# 3   2022/01/25 7:26:31 PM EST  ...  Introduction to Data Science | DATA 601;Ethica...
# 4  2022/01/26 11:15:22 AM EST  ...  Introduction to Data Science | DATA 601;Platfo...
#
# [5 rows x 13 columns]

# %%
df.tail()
# Out:
#                      Timestamp  ...             12. Other courses taking this semester
# 21   2022/01/31 6:01:52 PM EST  ...  Platforms for Big Data Processing | DATA 603;E...
# 22   2022/01/31 6:37:33 PM EST  ...  Intro to Data Analysis and Machine Learning | ...
# 23   2022/01/31 6:50:31 PM EST  ...  Intro to Data Analysis and Machine Learning | ...
# 24  2022/01/31 11:36:40 PM EST  ...  Platforms for Big Data Processing | DATA 603;E...
# 25   2022/02/01 9:01:01 AM EST  ...  Capstone in Data Science | DATA 606;Special To...
#
# [5 rows x 13 columns]

# %%
df.sample(3)
# Out:
#                      Timestamp  ...             12. Other courses taking this semester
# 21   2022/01/31 6:01:52 PM EST  ...  Platforms for Big Data Processing | DATA 603;E...
# 13  2022/01/31 12:28:01 PM EST  ...            Introduction to Data Science | DATA 601
# 12   2022/01/30 8:59:51 PM EST  ...  Intro to Data Analysis and Machine Learning | ...
#
# [3 rows x 13 columns]

# %%
df.describe()
# Out:
#                         Timestamp  ...   12. Other courses taking this semester
# count                          26  ...                                       26
# unique                         26  ...                                       20
# top     2022/01/25 5:14:48 PM EST  ...  Introduction to Data Science | DATA 601
# freq                            1  ...                                        3
#
# [4 rows x 13 columns]

# %%
df.dtypes
# Out:
# Timestamp                                            object
# 1. My primary educational background                 object
# 2. My primary job function                           object
# 3. My level of computer programing knowledge         object
# 4. My level of Python progrmming knowledge           object
# 5. My level of Statistics knowledge                  object
# 6. My Familarity with GitHub                         object
# 7. My gender                                         object
# 8. My Birth Year                                     object
# 9. What do you enjoy doing in your leisure time?     object
# 10. What do you expect to get out of this course?    object
# 11. What is your long-term career goal?              object
# 12. Other courses taking this semester               object
# dtype: object

# %% [markdown]
# # 2.Data Aggression

# %%
df_groupby = df.groupby("2. My primary job function")["Timestamp"].count().reset_index()
df_groupby
# Out:
#                      2. My primary job function  Timestamp
# 0                     Business/service-oriented          1
# 1                             Full-time Student         16
# 2  Seeking part time employment while at school          1
# 3               Technology/engineering-oriented          8

# %%
df_groupby.columns = ["Job Function", "Count"]
df_groupby
# Out:
#                                    Job Function  Count
# 0                     Business/service-oriented      1
# 1                             Full-time Student     16
# 2  Seeking part time employment while at school      1
# 3               Technology/engineering-oriented      8

# %% [markdown]
# ## 3.Data Visualization

# %%
fig = px.pie(df_groupby, values='Count', names='Job Function', title='Data 690 Class Job Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(df_groupby, y='Count', x='Job Function', color="Job Function", title='Data 690 Class Job Distribution')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
