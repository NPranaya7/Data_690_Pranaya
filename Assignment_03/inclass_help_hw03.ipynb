# %% [markdown]
# <a href="https://colab.research.google.com/github/NPranaya7/Data_690_Pranaya/blob/main/Assignment_03/inclass_help_hw03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Inclass session_03
# - Date:14/02/2022
# - N Pranay manikanta
# - MT50255

# %%
x = [1,2,3,"pranay","mani",45,7]
print (x)
# Out:
# [1, 2, 3, 'pranay', 'mani', 45, 7]

# %%
for i in x:
    print(i, end=" * ")
# Out:
# 1 * 2 * 3 * pranay * mani * 45 * 7 *

# %%
import random

# %%
random.randint(1, 7)
# Out:
# 7

# %%
for i in range(10):
    print(random.randint(0,9))
# Out:
# 5
# 6
# 5
# 7
# 9
# 7
# 4
# 2
# 6
# 8

# %%
for i in range(10):
    print(random.randint(0,9),end=" ")
# Out:
# 6 2 2 6 2 1 3 0 3 8

# %%
for i in range(10):
    for j in range(10):
        print(random.randint(0,9),end=" ")
    print()
# Out:
# 4 4 4 8 0 2 8 7 5 7
# 0 3 0 8 3 1 0 8 4 9
# 1 4 8 1 6 2 5 9 9 1
# 6 4 4 1 5 3 1 5 3 6
# 9 8 9 9 1 6 8 3 6 2
# 6 6 2 9 8 4 1 5 0 2
# 5 4 7 9 9 6 8 8 0 0
# 0 1 6 9 5 4 6 2 7 6
# 1 8 4 2 5 6 0 6 0 6
# 1 2 0 8 8 8 4 4 9 3

# %%
for i in range(10):
    for j in range(10):
        a = random.randint(0,9)
        odd=a
        if a in [1,3,5,7,9]:
          print("@",end=" ")
        else:
          print(a,end=" ")
    print()
# Out:
# 6 @ 8 0 6 @ @ @ @ @
# @ 8 8 @ 8 @ @ 6 2 @
# 8 @ @ 6 @ @ 8 @ @ @
# @ 0 @ 2 0 @ @ @ 0 @
# @ 6 @ 4 4 4 0 @ @ @
# @ 0 @ 6 @ @ 4 2 @ 8
# @ 0 @ 2 @ 0 8 6 4 4
# @ @ 2 8 4 @ 0 @ @ 8
# @ 6 @ @ @ 8 @ 6 @ 8
# 4 @ 2 @ 6 4 0 8 @ @
