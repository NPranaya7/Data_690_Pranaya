# %% [markdown]
# <a href="https://colab.research.google.com/github/NPranaya7/Data_690_Pranaya/blob/main/Project_Part%20B_draft/Project_Part_B_Draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part B Draft
# - Date:01/04/2022
# - MT50255
# - Narava Pranay manikanta

# %% [markdown]
# # How Country GDP effect Unemployment rate and What are the other Causes of Unemployment

# %% [markdown]
# ### Intoduction:
# Unemployment is When a person is ready to work but unable to secure a job. Mainly unemployment is caused by the three factors
# - Structural - Structural Unemployment Happen when the required skillset is not matched for the job demanded or when a worker is having a job but not able to attend the work place due to technical issues.
# - Frictional - Frictinoal unemployment is happen when a person is looking for a job change or in between the jobs.
# - Cyclical - Cyclical Unemployment Happens when the Economy faces recession in other words when economy crashes. during this time Unemployment rate will increases.
#
# In this project we are looking at Okun's Law regarding Unemployment rate. Okun's Law state that their is a relationship between a country’s unemployment and economic growth rates.
# According to Okun's law, a country's gross domestic product (GDP) must expand at a pace of around 4% for one year in order to achieve a 1% reduction in unemployment.But their are
# some time where Okun's Law proved wrong especially during Americas 2008 recession. this project aim is to analysis the data from world bank using world development explorer tool to
# find how accurate is okun's law.

# %% [markdown]
# ## Analysis Topics
# - **Data Source:**
#   -  World Development Explorer  https://www.worlddev.xyz/
#
# - **Topics:**
#   - Economy & Growth - GDP per capita, PPP (current international $)
#   -  Health - Population, total
#   - Education - Unemployment, total (% of total labor force) (modeled ILO estimate)
#   - Economy & Growth - Inflation, consumer prices (annual %)
# - **Countries:**
#   - United States
#   - United Kingdom
#   - India
#   - China
# - **Time Plot Between:**
#   - 2006 to 2019

# %%
import pandas as pd
import plotly
import plotly.express as px

DATA = "https://raw.githubusercontent.com/NPranaya7/Data_690_Pranaya/main/Project_Part%20B_draft/wdi_data%20(2).csv"

# %%
df = pd.read_csv(DATA)

df.sample(10)
# Out:
#        Unnamed: 0  Year          value          indicator Country Code  \
# 7001         7001  2012       1.059913     FP.CPI.TOTL.ZG          NZL
# 5245         5245  2014       6.864000     SL.UEM.TOTL.ZS          VEN
# 10348       10348  2016  619438.000000        SP.POP.TOTL          SLB
# 6456         6456  2009       0.774768     FP.CPI.TOTL.ZG          ITA
# 6965         6965  2010       9.326504     FP.CPI.TOTL.ZG          NPL
# 4645         4645  2016       5.900000     SL.UEM.TOTL.ZS          ROU
# 3682         3682  2019       5.020000     SL.UEM.TOTL.ZS          GIN
# 2150         2150  2019    1777.303893  NY.GDP.PCAP.PP.CD          SLE
# 6033         6033  2006       4.037124     FP.CPI.TOTL.ZG          SLV
# 2572         2572  2015   64901.880051  NY.GDP.PCAP.PP.CD          ARE
#
#                Country Name                      Region         Income Group  \
# 7001            New Zealand         East Asia & Pacific          High income
# ...

# %%
df_2019_GDP_all = df.query("Year == 2019").query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_2019_GDP_all.sample(5)
# Out:
#       Unnamed: 0  Year          value          indicator Country Code  \
# 1940        1940  2019    9291.726915  NY.GDP.PCAP.PP.CD          PHL
# 760          760  2019    9147.261066  NY.GDP.PCAP.PP.CD          SLV
# 1242        1242  2019   27466.220619  NY.GDP.PCAP.PP.CD          KAZ
# 1436        1436  2019  117341.915064  NY.GDP.PCAP.PP.CD          LUX
# 906          906  2019   15623.152959  NY.GDP.PCAP.PP.CD          GEO
#
#      Country Name                      Region         Income Group  \
# 1940  Philippines         East Asia & Pacific  Lower middle income
# 760   El Salvador  Latin America & Caribbean   Lower middle income
# 1242   Kazakhstan       Europe & Central Asia  Upper middle income
# 1436   Luxembourg       Europe & Central Asia          High income
# 906       Georgia       Europe & Central Asia  Upper middle income
#
#         Lending Type
# 1940            IBRD
# 760             IBRD
# 1242            IBRD
# 1436  Not classified
# 906             IBRD

# %%
df_2019_GDP_all_sort = df_2019_GDP_all.sort_values(by="value", ascending=False)

df_2019_GDP_all_sort.head()
# Out:
#       Unnamed: 0  Year          value          indicator Country Code  \
# 1450        1450  2019  132654.896700  NY.GDP.PCAP.PP.CD          MAC
# 1436        1436  2019  117341.915064  NY.GDP.PCAP.PP.CD          LUX
# 2164        2164  2019  102573.401768  NY.GDP.PCAP.PP.CD          SGP
# 1996        1996  2019   93771.125306  NY.GDP.PCAP.PP.CD          QAT
# 1158        1158  2019   87379.692966  NY.GDP.PCAP.PP.CD          IRL
#
#           Country Name                      Region Income Group  \
# 1450  Macao SAR, China         East Asia & Pacific  High income
# 1436        Luxembourg       Europe & Central Asia  High income
# 2164         Singapore         East Asia & Pacific  High income
# 1996             Qatar  Middle East & North Africa  High income
# 1158           Ireland       Europe & Central Asia  High income
#
#         Lending Type
# 1450  Not classified
# 1436  Not classified
# 2164  Not classified
# 1996  Not classified
# 1158  Not classified

# %%
fig = px.bar(
    df_2019_GDP_all_sort, 
    x="Country Name", 
    labels={"value":"2019 Bar Plot of all countries GDP per capita", "Country Name":""},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_gdp = df.query("indicator == 'NY.GDP.PCAP.PP.CD'").query("Year == 2019")
df_gdp = df_gdp[df_gdp["Country Code"].isin(["CHN","IND", "GBR", "USA","QAT"])]
df_gdp_sort = df_gdp.sort_values(by="value", ascending=False)
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 529 to 2604
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5 non-null      int64
#  1   Year          5 non-null      int64
#  2   value         5 non-null      float64
#  3   indicator     5 non-null      object
#  4   Country Code  5 non-null      object
#  5   Country Name  5 non-null      object
#  6   Region        5 non-null      object
#  7   Income Group  5 non-null      object
#  8   Lending Type  5 non-null      object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 400.0+ bytes

# %%
fig = px.bar(
    df_gdp_sort, 
    x="Country Name", 
    labels={"value":"2019 GDP per capita Bar Plot."},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Comparing GDP Per Capita from 2016 to 2020 of Four Major Economies"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df_gdp_sort, values='value', names='Country Name', title='2019 total GDP per capita,Comparision between India, United states, China, United kingdom,Qatar.',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_2019_Unemp_all = df.query("Year == 2019").query("indicator == 'SL.UEM.TOTL.ZS'")

df_2019_Unemp_all_sort = df_2019_Unemp_all.sort_values(by="value", ascending=False)


fig = px.bar(
    df_2019_Unemp_all_sort, 
    x="Country Name", 
    labels={"value":"2019 total Unemployment Rate", "Country Name":""},
    y="value",
    title='2019 total Unemployment Rate of All countries',
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5]
)

fig.update_layout(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_gdp2 = df.query("indicator == 'SL.UEM.TOTL.ZS'").query("Year == 2019")
df_gdp2 = df_gdp2[df_gdp2["Country Code"].isin(["CHN","IND", "GBR", "USA","QAT"])]
df_gdp2_sort = df_gdp2.sort_values(by="value", ascending=False)

fig = px.bar(
    df_gdp2_sort, 
    x="Country Name", 
    labels={"value":"2019 total Unemployment Rate"},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Comparing Unemployment Rate from 2016 to 2020 of Four Major Economies"
)

fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.pie(df_gdp2_sort, values='value', names='Country Name', title='2019 Pie chart of Unemployment Rate, Comparision between India, United states, China, United kingdom,Qatar.',template=list(plotly.io.templates.keys())[5])
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["CHN","IND", "GBR", "USA","QAT"])]

fig = px.line(
    df_GDP_all, 
    x="Year", 
    labels={"value":"GDP Per Capita"},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Comparing GDP Per Capita from 2016 to 2020 of Four Major Economies"

)


fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_unemp_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_unemp_all = df_unemp_all[df_unemp_all["Country Code"].isin(["CHN","IND", "GBR", "USA","QAT"])]

fig = px.line(
    df_unemp_all, 
    x="Year", 
    labels={"value":"GDP Per Capita"},
    y="value",
    color="Country Name",
    height=800,
    template=list(plotly.io.templates.keys())[5],
    title="Comparing Unemployment Rate from 2006 to 2020 of Four Major Economies"

)


fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_un_all = df_un_all[df_un_all["Country Code"].isin(["IND"])]
i2 = df_un_all["value"]
i5 = df_un_all["Year"]

df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["IND"])]
i3 = df_GDP_all["value"]

df2 = pd.DataFrame({ 'Year': i5.values, 'GDP': i3.values, 'UNEMP': i2.values})
df2
# Out:
#     Year          GDP  UNEMP
# 0   2006  3237.294799  5.601
# 1   2007  3525.314454  5.572
# 2   2008  3650.942943  5.414
# 3   2009  3912.418211  5.544
# 4   2010  4236.744348  5.546
# 5   2011  4493.669466  5.426
# 6   2012  4861.156152  5.414
# 7   2013  5057.233414  5.424
# 8   2014  5233.882343  5.436
# 9   2015  5464.859178  5.435
# 10  2016  5839.864817  5.423
# 11  2017  6182.922109  5.358
# 12  2018  6675.361294  5.330
# 13  2019  6997.863988  5.270

# %%
fig = px.scatter(df2, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},
    height=800,
    trendline="lowess",
    text="Year",
    title="Indias GDP Vs Unemployment Rate from 2006 to 2019",
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_un_all = df_un_all[df_un_all["Country Code"].isin(["CHN"])]
c2 = df_un_all["value"]
c5 = df_un_all["Year"]

df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["CHN"])]
c3 = df_GDP_all["value"]

df3 = pd.DataFrame({ 'Year': c5.values, 'GDP': c3.values, 'UNEMP': c2.values})
df3
# Out:
#     Year           GDP  UNEMP
# 0   2006   5836.573437   4.43
# 1   2007   6810.603900   4.35
# 2   2008   7574.224455   4.59
# 3   2009   8307.849519   4.72
# 4   2010   9253.765188   4.53
# 5   2011  10292.940478   4.55
# 6   2012  11168.697298   4.57
# 7   2013  11872.497381   4.59
# 8   2014  12480.338530   4.61
# 9   2015  12897.502287   4.63
# 10  2016  13483.377267   4.53
# 11  2017  14243.532611   4.44
# 12  2018  15497.359995   4.28
# 13  2019  16653.338844   4.52

# %%
fig = px.scatter(df3, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},
    height=800,
    trendline="lowess",
    text="Year",
    title="Chians GDP Vs Unemployment Rate from 2006 to 2019",
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_un_all = df_un_all[df_un_all["Country Code"].isin(["USA"])]
U2 = df_un_all["value"]
U5 = df_un_all["Year"]

df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["USA"])]
U3 = df_GDP_all["value"]

df4 = pd.DataFrame({ 'Year': U5.values, 'GDP': U3.values, 'UNEMP': U2.values})
df4
# Out:
#     Year           GDP  UNEMP
# 0   2006  46298.731444   4.62
# 1   2007  47975.967696   4.62
# 2   2008  48382.558449   5.78
# 3   2009  47099.980471   9.25
# 4   2010  48466.657603   9.63
# 5   2011  49882.558132   8.95
# 6   2012  51602.931046   8.07
# 7   2013  53106.536767   7.37
# 8   2014  55049.988327   6.17
# 9   2015  56863.371496   5.28
# 10  2016  58021.400500   4.87
# 11  2017  60109.655726   4.36
# 12  2018  63064.418410   3.90
# 13  2019  65279.529026   3.67

# %%
fig = px.scatter(df4, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},title="USA GDP Vs Unemployment Rate from 2006 to 2019",
    height=800,
    trendline="lowess",
    text="Year",
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_un_all = df_un_all[df_un_all["Country Code"].isin(["GBR"])]
B2 = df_un_all["value"]
B5 = df_un_all["Year"]

df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["GBR"])]
B3 = df_GDP_all["value"]

df5 = pd.DataFrame({ 'Year': B5.values, 'GDP': B3.values, 'UNEMP': B2.values})
df5
# Out:
#     Year           GDP  UNEMP
# 0   2006  34845.591772   5.35
# 1   2007  35695.298490   5.26
# 2   2008  36863.584760   5.62
# 3   2009  35212.420477   7.54
# 4   2010  36576.586540   7.79
# 5   2011  37379.290966   8.04
# 6   2012  38514.026169   7.88
# 7   2013  40218.747256   7.52
# 8   2014  41580.602488   6.11
# 9   2015  42912.875094   5.30
# 10  2016  44635.299559   4.81
# 11  2017  46372.386604   4.33
# 12  2018  47573.488016   4.00
# 13  2019  49041.463548   3.74

# %%
fig = px.scatter(df5, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},title="UK GDP Vs Unemployment Rate from 2006 to 2019",
    height=800,
    trendline="lowess",
    text="Year",
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'")
df_un_all = df_un_all[df_un_all["Country Code"].isin(["GBR","USA","IND","CHN"])]
A6 = df_un_all["Country Name"]
A2 = df_un_all["value"]
A5 = df_un_all["Year"]

df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'")
df_GDP_all = df_GDP_all[df_GDP_all["Country Code"].isin(["GBR","USA","IND","CHN"])]
A3 = df_GDP_all["value"]


df6 = pd.DataFrame({ 'Year': A5.values, 'GDP': A3.values, 'UNEMP': A2.values, 'country': A6.values})

df6
# Out:
#     Year           GDP  UNEMP         country
# 0   2006   5836.573437  4.430           China
# 1   2007   6810.603900  4.350           China
# 2   2008   7574.224455  4.590           China
# 3   2009   8307.849519  4.720           China
# 4   2010   9253.765188  4.530           China
# 5   2011  10292.940478  4.550           China
# 6   2012  11168.697298  4.570           China
# 7   2013  11872.497381  4.590           China
# 8   2014  12480.338530  4.610           China
# 9   2015  12897.502287  4.630           China
# 10  2016  13483.377267  4.530           China
# 11  2017  14243.532611  4.440           China
# 12  2018  15497.359995  4.280           China
# 13  2019  16653.338844  4.520           China
# 14  2006   3237.294799  5.601           India
# 15  2007   3525.314454  5.572           India
# 16  2008   3650.942943  5.414           India
# 17  2009   3912.418211  5.544           India
# 18  2010   4236.744348  5.546           India
# ...

# %%
fig = px.scatter(df6, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},title="GDP Vs Unemployment Rate from 2006 to 2019 of Four Major Economies",
    height=800,
    #trendline="lowess",
    #text="Year",
    color="country",
  
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom right")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_GDP_all = df.query("indicator == 'NY.GDP.PCAP.PP.CD'").query("Year == 2019")
#df_un_all = df_un_all[df_un_all["Country Code"].isin]
Av3 = df_GDP_all["value"]
Av7 = df_GDP_all["Country Name"]

# %%
df_un_all = df.query("indicator == 'SL.UEM.TOTL.ZS'").query("Year == 2019")
#df_un_all = df_un_all[df_un_all["Country Code"].isin]
Av6 = df_un_all["Country Name"]
Av2 = df_un_all["value"]
#Av5 = df_un_all["Year"]

# %%
h = {'GDP': Av3.values, 'UNEMP': Av2.values, 'country': Av6.values}
df7 = pd.DataFrame.from_dict(h, orient='index')
df7 = df7.transpose()
df8 = df7[0:186]

df8
# Out:
#               GDP   UNEMP                country
# 0     2152.366489  11.217            Afghanistan
# 1    14012.976435   11.47                Albania
# 2    12009.248208  10.513                Algeria
# 3     6952.419362   7.421                 Angola
# 4      22774.1742    9.84              Argentina
# ..            ...     ...                    ...
# 181  13346.475877    2.04                Vietnam
# 182  71150.542141  12.468  Virgin Islands (U.S.)
# 183  49041.463548   25.34     West Bank and Gaza
# 184  65279.529026  13.056            Yemen, Rep.
# 185  24006.786939   12.52                 Zambia
#
# [186 rows x 3 columns]

# %%
fig = px.scatter(df8, x="GDP", y="UNEMP",labels={"GDP":"GDP Per Capita", "UNEMP":"Unemployment Rate"},title="2019 GDP Vs Unemployment Rate of All Countries",
    height=800,
    trendline="ols",
    #text="Year",
    color="country",
  
    template=list(plotly.io.templates.keys())[5])
fig.update_layout(showlegend=True)
fig.update_traces(textposition="bottom right")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# The relationship between economic growth and the unemployment rate may be wobbly in the short term. It's not uncommon for the unemployment rate to continue to fall after other broad indicators of economic activity have improved. As a result, it is known as a lagging economic indicator. Some organizations may have inefficient personnel on their payrolls since dismissing off workers when product demand decreases and rehiring them when product demand increases has costs. This is one reason why unemployment may not fall significantly when economic growth picks up after a recession ends. As a consequence, firms may be able to boost output to meet increased demand without recruiting new workers at the start of a comeback.
#
# Overall, Okun's rule is widely regarded as one of the most basic and practical approaches to studying the link between economic growth and unemployment rate. One of the main advantages of Okun's rule is its simplicity in saying that if the economy expands at a rate of 2% higher than anticipated, unemployment would fall by 1%. However, depending on it to create particular unemployment projections based on economic growth trends does not work very well. For example, it has been found to fluctuate over time and be influenced by more uncommon economic conditions, such as jobless recoveries and the 2008 financial crisis, since it was first researched.
# Analysis may get quite complex due to the complexity of the inputs, the many time periods that can be employed, and the inherent uncertainty that comes with performing economic regressions. Okun's rule may not be completely accurate, but it can assist frame discussions about economic growth and how unemployment affects it.
#
# ## Conclusion:
# - From the Scatter plot We now Understand that As the GDP progress the Unemployment is reducing in the Country
# - but althought GDP and Unemployment Rate correlates but few time it Varies like during recision in 2008 at that time as the GDP progress the unemployement is also Incresed in united states and united kingdom
# - so that many scientist and analysts and economists  argue that it is a inverse relationship between the GDP and Unemployment rate
# - in my opinion the unemployment is related to GDP but as well as other factors also that causes the unemployment rate to increses or decreses.
